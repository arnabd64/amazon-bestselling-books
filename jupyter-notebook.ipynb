# %% [markdown]
# # Amazon top 50 bestselling books
#
# Source : [Kaggle.io](https://www.kaggle.com/sootersaalu/amazon-top-50-bestselling-books-2009-2019)
#
# Dataset contains for each year from 2009 to 2019, the Top 50 best-selling books for that respective year.
# There are a total of 550 entries.
#
# __Index__
#
# 1. Data Import and Initial Overview
# 2. Summary of Data
# 3. Visualizations

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

# %% [markdown]
# ## 1. Data Import and Initial Overview
#
# ### 1.1 Data Import

# %%
books = pd.read_csv('books.csv')
books.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
# ### 1.2 Initial Overview

# %%
# Sorting dataset on Year and Book Name
books.sort_values(by = ['Year','Name'], inplace = True)
books.reset_index(inplace = True)
books.head(10)
# Out:
#    index                                               Name            Author  \
# 0     14  Act Like a Lady, Think Like a Man: What Men Re...      Steve Harvey
# 1     25  Arguing with Idiots: How to Stop Small Minds a...        Glenn Beck
# 2     38          Breaking Dawn (The Twilight Saga, Book 4)   Stephenie Meyer
# 3     50        Crazy Love: Overwhelmed by a Relentless God      Francis Chan
# 4     60  Dead And Gone: A Sookie Stackhouse Novel (Sook...  Charlaine Harris
# 5     72      Diary of a Wimpy Kid: The Last Straw (Book 3)       Jeff Kinney
# 6     78  Divine Soul Mind Body Healing and Transmission...      Zhi Gang Sha
# 7     80  Dog Days (Diary of a Wimpy Kid, Book 4) (Volum...       Jeff Kinney
# 8     91  Eat This Not That! Supermarket Survival Guide:...   David Zinczenko
# 9     92  Eat This, Not That! Thousands of Simple Food S...   David Zinczenko
#
#    User Rating  Reviews  Price  Year        Genre
# 0          4.6     5013     17  2009  Non Fiction
# 1          4.6      798      5  2009  Non Fiction
# 2          4.6     9769     13  2009      Fiction
# 3          4.7     1542     14  2009  Non Fiction
# 4          4.6     1541      4  2009      Fiction
# 5          4.8     3837     15  2009      Fiction
# 6          4.6       37      6  2009  Non Fiction
# 7          4.8     3181     12  2009      Fiction
# 8          4.5      720      1  2009  Non Fiction
# 9          4.3      956     14  2009  Non Fiction

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        550 non-null    int64
#  1   Name         550 non-null    object
#  2   Author       550 non-null    object
#  3   User Rating  550 non-null    float64
#  4   Reviews      550 non-null    int64
#  5   Price        550 non-null    int64
#  6   Year         550 non-null    int64
#  7   Genre        550 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 34.5+ KB

# %%
print("Missing Values \n", books.isnull().sum())
# Out:
# Missing Values
#  index          0
# Name           0
# Author         0
# User Rating    0
# Reviews        0
# Price          0
# Year           0
# Genre          0
# dtype: int64

# %%
print("Duplicate entries", books.duplicated().sum())
# Out:
# Duplicate entries 0

# %% [markdown]
# __Note:__
# 1. There are no missing values or duplicate entries.
# 2. Out of 7 variables, 4 are numerical and 3 are text type.

# %% [markdown]
# ## 2. Summary of Data
#
# ### 2.1 Top Performing

# %% [markdown]
# #### 2.1.1 Top 10 Reviewed Books

# %%
book2 = books.groupby(by = 'Name').aggregate({'Author':'first','User Rating':'mean','Reviews':'mean','Price':'max','Genre':'first'})
results = book2.sort_values(by = ['Reviews','User Rating'], ascending = False)
results.loc[:, ['Author','Reviews','User Rating','Genre']].head(10)
# Out:
#                                                             Author  Reviews  \
# Name
# Where the Crawdads Sing                                Delia Owens  87841.0
# The Girl on the Train                                Paula Hawkins  79446.0
# Becoming                                            Michelle Obama  61133.0
# Gone Girl                                            Gillian Flynn  57271.0
# The Fault in Our Stars                                  John Green  50482.0
# The Nightingale: A Novel                            Kristin Hannah  49288.0
# Fifty Shades of Grey: Book One of the Fifty Sha...       E L James  47265.0
# The Martian                                              Andy Weir  39459.0
# All the Light We Cannot See                          Anthony Doerr  36348.0
# The Alchemist                                         Paulo Coelho  35799.0
#
#                                                     User Rating        Genre
# Name
# Where the Crawdads Sing                                     4.8      Fiction
# The Girl on the Train                                       4.1      Fiction
# Becoming                                                    4.8  Non Fiction
# Gone Girl                                                   4.0      Fiction
# The Fault in Our Stars                                      4.7      Fiction
# The Nightingale: A Novel                                    4.8      Fiction
# Fifty Shades of Grey: Book One of the Fifty Sha...          3.8      Fiction
# The Martian                                                 4.7      Fiction
# All the Light We Cannot See                                 4.6      Fiction
# The Alchemist                                               4.7      Fiction

# %% [markdown]
# #### 2.1.2 Top 10 Rated Books

# %%
results.sort_values(by = ['User Rating','Reviews'], ascending = False, inplace = True)
results.loc[:, ['Author','User Rating','Reviews','Genre']].head(10)
# Out:
#                                                                    Author  \
# Name
# Harry Potter and the Chamber of Secrets: The Il...           J.K. Rowling
# Brown Bear, Brown Bear, What Do You See?                  Bill Martin Jr.
# Dog Man: Fetch-22: From the Creator of Captain ...             Dav Pilkey
# Last Week Tonight with John Oliver Presents A D...             Jill Twiss
# Harry Potter and the Sorcerer's Stone: The Illu...           J.K. Rowling
# Wrecking Ball (Diary of a Wimpy Kid Book 14)                  Jeff Kinney
# Strange Planet (Strange Planet Series)                     Nathan W. Pyle
# Dog Man: For Whom the Ball Rolls: From the Crea...             Dav Pilkey
# The Wonderful Things You Will Be                    Emily Winfield Martin
# The Magnolia Story                                            Chip Gaines
#
#                                                     User Rating  Reviews  \
# Name
# Harry Potter and the Chamber of Secrets: The Il...          4.9  19622.0
# Brown Bear, Brown Bear, What Do You See?                    4.9  14344.0
# Dog Man: Fetch-22: From the Creator of Captain ...          4.9  12619.0
# Last Week Tonight with John Oliver Presents A D...          4.9  11881.0
# Harry Potter and the Sorcerer's Stone: The Illu...          4.9  10052.0
# Wrecking Ball (Diary of a Wimpy Kid Book 14)                4.9   9413.0
# Strange Planet (Strange Planet Series)                      4.9   9382.0
# Dog Man: For Whom the Ball Rolls: From the Crea...          4.9   9089.0
# The Wonderful Things You Will Be                            4.9   8842.0
# The Magnolia Story                                          4.9   7861.0
#
#                                                           Genre
# Name
# Harry Potter and the Chamber of Secrets: The Il...      Fiction
# Brown Bear, Brown Bear, What Do You See?                Fiction
# Dog Man: Fetch-22: From the Creator of Captain ...      Fiction
# Last Week Tonight with John Oliver Presents A D...      Fiction
# Harry Potter and the Sorcerer's Stone: The Illu...      Fiction
# Wrecking Ball (Diary of a Wimpy Kid Book 14)            Fiction
# Strange Planet (Strange Planet Series)                  Fiction
# Dog Man: For Whom the Ball Rolls: From the Crea...      Fiction
# The Wonderful Things You Will Be                        Fiction
# The Magnolia Story                                  Non Fiction

# %% [markdown]
# #### 2.1.3 Highest Rated Free books

# %%
results = book2[book2.Price == 0]
results = results.sort_values(by = ['User Rating','Reviews'], ascending = False)
results.loc[:, ['Author','User Rating','Reviews','Genre']]
# Out:
#                                                                               Author  \
# Name
# Little Blue Truck                                                     Alice Schertle
# Diary of a Wimpy Kid: Hard Luck, Book 8                                  Jeff Kinney
# The Getaway                                                              Jeff Kinney
# Cabin Fever (Diary of a Wimpy Kid, Book 6)                               Jeff Kinney
# The Constitution of the United States               Delegates of the Constitutional
#
# Frozen (Little Golden Book)                                                RH Disney
# The Short Second Life of Bree Tanner: An Eclips...                   Stephenie Meyer
# JOURNEY TO THE ICE P                                                       RH Disney
#
#                                                     User Rating  Reviews  \
# Name
# Little Blue Truck                                           4.9   1884.0
# Diary of a Wimpy Kid: Hard Luck, Book 8                     4.8   6812.0
# The Getaway                                                 4.8   5836.0
# Cabin Fever (Diary of a Wimpy Kid, Book 6)                  4.8   4505.0
# The Constitution of the United States                       4.8   2774.0
# Frozen (Little Golden Book)                                 4.7   3642.0
# The Short Second Life of Bree Tanner: An Eclips...          4.6   2122.0
# JOURNEY TO THE ICE P                                        4.6    978.0
#
#                                                           Genre
# Name
# Little Blue Truck                                       Fiction
# Diary of a Wimpy Kid: Hard Luck, Book 8                 Fiction
# The Getaway                                             Fiction
# Cabin Fever (Diary of a Wimpy Kid, Book 6)              Fiction
# The Constitution of the United States               Non Fiction
# Frozen (Little Golden Book)                             Fiction
# The Short Second Life of Bree Tanner: An Eclips...      Fiction
# JOURNEY TO THE ICE P                                    Fiction

# %% [markdown]
# #### 2.1.4 Most Reviewed Non-Fiction

# %%
results = book2[book2.Genre == 'Non Fiction']
results = results.sort_values(by = ['Reviews','User Rating'], ascending = False)
results.loc[:, ['Author','User Rating','Reviews']].head(10)
# Out:
#                                                                 Author  \
# Name
# Becoming                                                Michelle Obama
# Unbroken: A World War II Story of Survival, Res...   Laura Hillenbrand
# Educated: A Memoir                                       Tara Westover
# The Subtle Art of Not Giving a F*ck: A Counteri...         Mark Manson
# The 5 Love Languages: The Secret to Love that L...        Gary Chapman
# How to Win Friends & Influence People                    Dale Carnegie
# The Boys in the Boat: Nine Americans and Their ...  Daniel James Brown
# The Four Agreements: A Practical Guide to Perso...     Don Miguel Ruiz
# School Zone - Big Preschool Workbook - Ages 4 a...         School Zone
# The Life-Changing Magic of Tidying Up: The Japa...         Marie Kondō
#
#                                                     User Rating  Reviews
# Name
# Becoming                                                    4.8  61133.0
# Unbroken: A World War II Story of Survival, Res...          4.8  29673.0
# Educated: A Memoir                                          4.7  28729.0
# The Subtle Art of Not Giving a F*ck: A Counteri...          4.6  26490.0
# The 5 Love Languages: The Secret to Love that L...          4.8  25554.0
# How to Win Friends & Influence People                       4.7  25001.0
# The Boys in the Boat: Nine Americans and Their ...          4.8  23358.0
# The Four Agreements: A Practical Guide to Perso...          4.7  23308.0
# School Zone - Big Preschool Workbook - Ages 4 a...          4.8  23047.0
# The Life-Changing Magic of Tidying Up: The Japa...          4.5  22641.0

# %% [markdown]
# #### 2.1.5 Most Reviewed Fiction

# %%
results = book2[book2.Genre == 'Fiction']
results = results.sort_values(by = ['Reviews','User Rating'], ascending = False)
results.loc[:, ['Author','User Rating','Reviews']].head(10)
# Out:
#                                                             Author  \
# Name
# Where the Crawdads Sing                                Delia Owens
# The Girl on the Train                                Paula Hawkins
# Gone Girl                                            Gillian Flynn
# The Fault in Our Stars                                  John Green
# The Nightingale: A Novel                            Kristin Hannah
# Fifty Shades of Grey: Book One of the Fifty Sha...       E L James
# The Martian                                              Andy Weir
# All the Light We Cannot See                          Anthony Doerr
# The Alchemist                                         Paulo Coelho
# The Goldfinch: A Novel (Pulitzer Prize for Fict...     Donna Tartt
#
#                                                     User Rating  Reviews
# Name
# Where the Crawdads Sing                                     4.8  87841.0
# The Girl on the Train                                       4.1  79446.0
# Gone Girl                                                   4.0  57271.0
# The Fault in Our Stars                                      4.7  50482.0
# The Nightingale: A Novel                                    4.8  49288.0
# Fifty Shades of Grey: Book One of the Fifty Sha...          3.8  47265.0
# The Martian                                                 4.7  39459.0
# All the Light We Cannot See                                 4.6  36348.0
# The Alchemist                                               4.7  35799.0
# The Goldfinch: A Novel (Pulitzer Prize for Fict...          3.9  33844.0

# %% [markdown]
# #### 2.1.6 Highest Rated books below USD 5

# %%
results = book2[book2.Price <= 5]
results = results.sort_values(by = ['User Rating','Price'], ascending = False)
results.head(10)
# Out:
#                                                                  Author  \
# Name
# Brown Bear, Brown Bear, What Do You See?                Bill Martin Jr.
# The Magnolia Story                                          Chip Gaines
# Dog Man: Brawl of the Wild: From the Creator of...           Dav Pilkey
# Little Blue Truck                                        Alice Schertle
# The Very Hungry Caterpillar                                  Eric Carle
# Creative Haven Owls Coloring Book (Adult Coloring)      Marjorie Sarnat
# Dear Zoo: A Lift-the-Flap Book                             Rod Campbell
# Goodnight Moon                                      Margaret Wise Brown
# Love You Forever                                          Robert Munsch
# The Going-To-Bed Book                                    Sandra Boynton
#
#                                                     User Rating  Reviews  \
# Name
# Brown Bear, Brown Bear, What Do You See?                    4.9  14344.0
# The Magnolia Story                                          4.9   7861.0
# Dog Man: Brawl of the Wild: From the Creator of...          4.9   7235.0
# Little Blue Truck                                           4.9   1884.0
# The Very Hungry Caterpillar                                 4.9  19546.0
# Creative Haven Owls Coloring Book (Adult Coloring)          4.8   3871.0
# Dear Zoo: A Lift-the-Flap Book                              4.8  10922.0
# Goodnight Moon                                              4.8   8837.0
# Love You Forever                                            4.8  18613.0
# The Going-To-Bed Book                                       4.8   5249.0
#
#                                                     Price        Genre
# Name
# Brown Bear, Brown Bear, What Do You See?                5      Fiction
# The Magnolia Story                                      5  Non Fiction
# Dog Man: Brawl of the Wild: From the Creator of...      4      Fiction
# Little Blue Truck                                       0      Fiction
# The Very Hungry Caterpillar                             5      Fiction
# Creative Haven Owls Coloring Book (Adult Coloring)      5  Non Fiction
# Dear Zoo: A Lift-the-Flap Book                          5      Fiction
# Goodnight Moon                                          5      Fiction
# Love You Forever                                        5      Fiction
# The Going-To-Bed Book                                   5      Fiction

# %% [markdown]
# ### 2.2 Statistical Summaries

# %%
books.describe()
# Out:
#             index  User Rating       Reviews       Price         Year
# count  550.000000   550.000000    550.000000  550.000000   550.000000
# mean   274.500000     4.618364  11953.281818   13.100000  2014.000000
# std    158.915596     0.226980  11731.132017   10.842262     3.165156
# min      0.000000     3.300000     37.000000    0.000000  2009.000000
# 25%    137.250000     4.500000   4058.000000    7.000000  2011.000000
# 50%    274.500000     4.700000   8580.000000   11.000000  2014.000000
# 75%    411.750000     4.800000  17253.250000   16.000000  2017.000000
# max    549.000000     4.900000  87841.000000  105.000000  2019.000000

# %%
books['Genre'].value_counts()
# Out:
# Non Fiction    310
# Fiction        240
# Name: Genre, dtype: int64

# %% [markdown]
# ## 3. Visualizations
#
# ### 3.1 Categorical variables

# %% [markdown]
# #### 3.1.1 Distribution of Genre

# %%
# Distribution of Genre
table = books.groupby(['Year','Genre']).aggregate({'Year':'count'})
table.rename(columns={'Year':'Year','Genre':'Genre','Year':'Count'}, inplace = True)

fig, ax = plt.subplots(1, 2, figsize=(24,8))
# Bar Plot
ax[0].bar(height = books['Genre'].value_counts(), x = pd.unique(books['Genre']))
ax[0].set_title('Overall distribution of Genre')
# Line Plot
sns.lineplot(data = table, x = 'Year', y = 'Count', hue = 'Genre')
ax[1].set_title('Number of Best-Sellers per Genre over time')
plt.show()

# %% [markdown]
# __Note:__
# 1. From 2009 - 2019, Non-Fiction(56.3%) books have more often been on the best-selling list than Non-Fiction(43.6%)
# 2. Post 2017, we see that Non-Fction books have more often been on the Best-Selling list.

# %% [markdown]
# #### 3.1.2 Top Books and Authors

# %%
# Summary of Book and Authors
table_book = books['Name'].value_counts()
table_book = table_book.head(10)

table_auth = books['Author'].value_counts()
table_auth = table_auth.head(25)

fig, ax = plt.subplots(1, 2, figsize=(30,10))
# Books
ax[0].barh(y = table_book.index, width = table_book.values)
ax[0].set_title('Number of Years a Book has been on Best-Selling List')
# Authors
ax[1].barh(y = table_auth.index, width = table_auth.values)
ax[1].set_title('Number of times Auhor has been on Best-Selling list')
plt.show()

# %% [markdown]
# __Note:__
#
# In the time frame of 2009 - 2019, _Jeff Kinney_ is the best selling author and _Publication Manual of the American Psycological Asociation (6th Edition)_ has always been on the best-selling list.

# %% [markdown]
# ### 3.2 Numerical variables

# %% [markdown]
# #### 3.2.1. Distribution of Price

# %%
fig, ax = plt.subplots(2,2, figsize = (24,12))
# Plot 1
sns.kdeplot(data = books, x = 'Price', ax = ax[0][0])
ax[0][0].set_title('Plot 1: Distribution of Price 2009 -- 2019')

# Plot 2
sns.kdeplot(data = books, x = 'Price', hue = 'Year', ax = ax[0][1])
ax[0][1].set_title('Plot 2: Distribution of Price vs Year')

# Plot 3
sns.kdeplot(data = books, x = 'Price', hue = 'Genre', ax = ax[1][0])
ax[1][0].set_title('Plot 3: Distribution of Price vs Genre')

# Plot 4
sns.lineplot(data = books, x = 'Year', y = 'Price', hue = 'Genre', ci = None, ax = ax[1][1])
ax[1][1].set_title('Plot 4: Time Series plot of Price of each Genre')

plt.show()

# %% [markdown]
# __Note:__
# 1. The overall price distribution has slightly postively skewed, i.e. An expensive book is more likely to be on the best-selling list than a cheap book. _(Plot 1)_
# 2. Overtime the price distribution is becomming tighter. As time is passing, Best-Selling books are coming from the a small price group rather a larger price group. _(Plot 2)_
# 3. Best-Selling Non-Fiction books are slightly more expensive than Fiction books. _(Plot 3)_
# 4. The price gap between Best-Selling Fiction and Non-Fiction books have narrowed down in 2018 and 2019. _(Plot 4)_

# %% [markdown]
# #### 3.2.2 Relation between Numerical variables

# %%
# Correlation
sns.heatmap(data = books.loc[:, ['User Rating','Price','Reviews']].corr(),
            cmap = 'YlOrBr', annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the Pair Grids and Correlation plot, we can conclude that there is no correlation between User Ratings, Reviews and Price of a Book.

# %% [markdown]
# #### 3.2.3 Reviews and Ratings

# %%
table_year = books.groupby(by = ['Year','Genre']).aggregate({'Reviews':'sum','User Rating':'mean'})

fig, ax = plt.subplots(1,2, figsize = (20,10))
sns.lineplot(data = table_year, x = 'Year', y = 'User Rating', hue = 'Genre', ax = ax[0])
ax[0].set_title('Plot 1: User rating vs Time')

sns.lineplot(data = table_year, x = 'Year', y = 'Reviews', hue = 'Genre', ax = ax[1])
ax[1].set_title('Plot 2: Reviews vs Time')
plt.show()
